# %%
import requests
import urllib.request
import time
from bs4 import BeautifulSoup
import csv
import pandas as pd

# %%
url = "http://www.record.com.mx/columnistas-francotirador/quirarte-seria-directivo-de-chivas-por-barato"
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text, 'lxml')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="es">
#  <head>
#   <link href="/apple-touch-icon.png" rel="apple-touch-icon"/>
#   <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="57x57"/>
#   <link href="/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
#   <link href="/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
#   <link href="/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
#   <link href="/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
#   <link href="/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
#   <link href="/apple-touch-icon-precomposed.png" rel="apple-touch-icon-precomposed"/>
#   <link href="/apple-touch-icon-76x76-precomposed.png" rel="apple-touch-icon-precomposed" sizes="76x76"/>
#   <link href="/apple-touch-icon-120x120-precomposed.png" rel="apple-touch-icon-precomposed" sizes="120x120"/>
# ...

# %%
[tag.decompose() for tag in soup(class_="titulo")]
# Out:
# [None, None, None, None, None, None, None, None]

# %%
[tag.decompose() for tag in soup("class_=twitter")]
# Out:
# []

# %%
[tag.decompose() for tag in soup(class_="descripcion")]
# Out:
# [None]

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="es">
#  <head>
#   <link href="/apple-touch-icon.png" rel="apple-touch-icon"/>
#   <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="57x57"/>
#   <link href="/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
#   <link href="/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
#   <link href="/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
#   <link href="/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
#   <link href="/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
#   <link href="/apple-touch-icon-precomposed.png" rel="apple-touch-icon-precomposed"/>
#   <link href="/apple-touch-icon-76x76-precomposed.png" rel="apple-touch-icon-precomposed" sizes="76x76"/>
#   <link href="/apple-touch-icon-120x120-precomposed.png" rel="apple-touch-icon-precomposed" sizes="120x120"/>
# ...

# %%
[tag.decompose() for tag in soup("titulo")]

# %%
all_tags =soup.findAll('a',class_='node_item')
all_tags

# %%
for link in all_tags:
        liga=link['href']
        print(liga)

# %%
print(link)

# %%
link=f'http://www.record.com.mx{liga}'
print(link)

# %%
for link in all_tags:
        liga=link['href']
        rec_link=f'http://www.record.com.mx{liga}'
        print(rec_link)

# %%
#csv_file=open('franco-notes.csv','w')
#csv_writer=csv.writer(csv_file)
#csv_writer.writerow(['headline'])

# %%
# Extracting all the <a> tags whose class name is 'result-title' into a list.
titles = soup.select('p')

# Extracting text from the the <a> tags, i.e. class titles.
for title in titles:
    print(title.text)
    print()

# %%
comments=[]

for article in rec_link:
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'lxml')
    #all_tags =soup.findAll('a',class_='node_item')
    
    titles = soup.select('p')
    for title in titles:
        data_file=title.text
        comments.append(data_file)
        print(data_file)
            
        print()

# %%
df = pd.DataFrame(comments)
df.head
